# %%
import numpy as np
import pandas as pd

# %%
rnd=np.random.RandomState(42)

# %%
df=pd.read_excel("S:\expenses.xlsx",header=None)
df.dropna(inplace=True,axis=0)
df=(df*80).T
df.columns=["Food&Drinks","AlcoholicItems","Cloothing&Footwear","Fuel&Power","HouseholdGoods","Health","Transport","Communication","Recreation&Culture","Education","Restaurants&Hotels","Goods&Services","AllExpenditure","OtherExpenditure"]
df.drop(0,axis=0,inplace=True)

# %%
df1=df.copy()

# %%
for i in range(2985):
    index=rnd.randint(len(df1))
    per=rnd.randint(40,81)

    pl_mi=rnd.randint(1,3)
    if pl_mi==1:
#         add data
        per_val=df1.iloc[index,:]+df1.iloc[index,:]*(per/100)
   
    else:
        per_val=df1.iloc[index,:]-df1.iloc[index,:]*(per/100)
        
    df1=df1.append(per_val)

# %% [markdown]
# ##### Data Created

# %%
df1
# Out:
#    Food&Drinks AlcoholicItems Cloothing&Footwear Fuel&Power HouseholdGoods  \
# 1         4824           1000               1984       6080           3224
# 2         4864            984               1992       6336           3320
# 3         4416           1032               1960       4584           3248
# 4         4512           1088               2000       5176           2944
# 5          160              0                 80        160             80
# ..         ...            ...                ...        ...            ...
# 1       1704.5        353.338            701.022    2148.29        1139.16
# 27      4381.7        674.108            1685.27    5729.92        3033.49
# 27     142.204        21.8776             54.694     185.96        98.4492
# 25     33.8609        6.77217            13.5443     37.247        20.3165
# 7      2814.19        562.837            1023.78    3231.46        1654.55
#
#      Health Transport Communication Recreation&Culture Education  \
# ...

# %%
df1["Total Exp"]=df1["AllExpenditure"]+df1["OtherExpenditure"]
df1["Income"]=np.nan
df1.reset_index(inplace=True)

# %%
df1.drop("index",axis=1)
# Out:
#      Food&Drinks AlcoholicItems Cloothing&Footwear Fuel&Power HouseholdGoods  \
# 0           4824           1000               1984       6080           3224
# 1           4864            984               1992       6336           3320
# 2           4416           1032               1960       4584           3248
# 3           4512           1088               2000       5176           2944
# 4            160              0                 80        160             80
# ...          ...            ...                ...        ...            ...
# 3008      1704.5        353.338            701.022    2148.29        1139.16
# 3009      4381.7        674.108            1685.27    5729.92        3033.49
# 3010     142.204        21.8776             54.694     185.96        98.4492
# 3011     33.8609        6.77217            13.5443     37.247        20.3165
# 3012     2814.19        562.837            1023.78    3231.46        1654.55
#
# ...

# %%
for i in range(len(df1)):
    tot=df1.loc[i,"Total Exp"]
    pert=rnd.randint(0,15)
    df1.loc[i,"Income"]=tot+tot*pert/100

# %%
for i in df1.columns:
    df1[i]=df1[i].apply(np.int64)

# %%
df1.drop("index",axis=1,inplace=True)

# %%
df1
# Out:
#       Food&Drinks  AlcoholicItems  Cloothing&Footwear  Fuel&Power  \
# 0            4824            1000                1984        6080
# 1            4864             984                1992        6336
# 2            4416            1032                1960        4584
# 3            4512            1088                2000        5176
# 4             160               0                  80         160
# ...           ...             ...                 ...         ...
# 3008         1704             353                 701        2148
# 3009         4381             674                1685        5729
# 3010          142              21                  54         185
# 3011           33               6                  13          37
# 3012         2814             562                1023        3231
#
#       HouseholdGoods  Health  Transport  Communication  Recreation&Culture  \
# 0               3224     592       6424           1504                6008
# ...

# %%
df1.to_csv("S:\InitialCommitDatabase.csv")

# %%
weights={
    
    'Food&Drinks':0.10,
    'AlcoholicItems':0.02,
    'Cloothing&Footwear':0.025,
    'Fuel&Power':0.10,
    'HouseholdGoods':0.06,
    'Health':0.010,
    'Transport':0.10,
    'Communication':0.02,
    'Recreation&Culture':0.07,
    'Education':0.01, 
    'Restaurants&Hotels':0.05,
    'Goods&Services':0.05,
    'AllExpenditure':1,
    'OtherExpenditure':0.10,
    'Total Exp':1,
    'Income':1
}

# %%
df1["Rating"]=np.nan

# %%
len(df1.columns)
# Out:
# 17

# %%
for i in range(len(df1)):
   
    c=0
    ratings=[0]*13
    for j in df1.columns:
        if j=="Rating" or j=='AllExpenditure' or j=='Total Exp' or j=='Income':
            continue
        ideal_bar=round(df1.loc[i,"Income"]*weights[j],2)
        val=df1.loc[i,j]
        if val<=ideal_bar:
            ratings[c]=1
        else:
            
            if val<0.10*ideal_bar+ideal_bar:
                 ratings[c]=2
            
            elif val<0.20*ideal_bar+ideal_bar:
                 ratings[c]=3

            elif val<0.30*ideal_bar+ideal_bar:
                 ratings[c]=4

            elif val<0.40*ideal_bar+ideal_bar:
                 ratings[c]=5

            elif val<0.50*ideal_bar+ideal_bar:
                 ratings[c]=6

            elif val<0.60*ideal_bar+ideal_bar:
                 ratings[c]=7

            elif val<0.70*ideal_bar+ideal_bar:
                 ratings[c]=8

            elif val<0.80*ideal_bar+ideal_bar:
                 ratings[c]=9
                
            elif val<ideal_bar+ideal_bar:
                 ratings[c]=10
            
            else:
                 ratings[c]=10
        c+=1
    
    print(np.mean(ratings))
    
    df1.loc[i,"Rating"]=round(np.mean(ratings),0)
# Out:
# 4.538461538461538
# 4.769230769230769
# 5.0
# 4.3076923076923075
# 2.5384615384615383
# 4.615384615384615
# 4.3076923076923075
# 3.6153846153846154
# 3.923076923076923
# 2.923076923076923
# 5.538461538461538
# 2.076923076923077
# 4.538461538461538
# 4.384615384615385
# 3.6153846153846154
# 3.0
# 2.5384615384615383
# 5.230769230769231
# 5.615384615384615
# 2.6923076923076925
# 1.9230769230769231
# 4.538461538461538
# 1.8461538461538463
# 3.076923076923077
# 3.5384615384615383
# 4.461538461538462
# 4.846153846153846
# 2.5384615384615383
# 5.384615384615385
# 4.923076923076923
# 1.8461538461538463
# 4.6923076923076925
# 4.538461538461538
# 2.6153846153846154
# 4.153846153846154
# 5.153846153846154
# 1.8461538461538463
# 5.461538461538462
# 4.846153846153846
# 3.6153846153846154
# 5.384615384615385
# 4.769230769230769
# 5.3076923076923075
# 3.6153846153846154
# 4.846153846153846
# 4.153846153846154
# 5.769230769230769
# 4.0
# 4.3076923076923075
# 4.153846153846154
# 4.615384615384615
# ...

# %%
df1
# Out:
#       Food&Drinks  AlcoholicItems  Cloothing&Footwear  Fuel&Power  \
# 0            4824            1000                1984        6080
# 1            4864             984                1992        6336
# 2            4416            1032                1960        4584
# 3            4512            1088                2000        5176
# 4             160               0                  80         160
# ...           ...             ...                 ...         ...
# 3008         1704             353                 701        2148
# 3009         4381             674                1685        5729
# 3010          142              21                  54         185
# 3011           33               6                  13          37
# 3012         2814             562                1023        3231
#
#       HouseholdGoods  Health  Transport  Communication  Recreation&Culture  \
# 0               3224     592       6424           1504                6008
# ...

# %%
df3=pd.DataFrame(columns=df1.columns)

# %%
df3
# Out:
# Empty DataFrame
# Columns: [Food&Drinks, AlcoholicItems, Cloothing&Footwear, Fuel&Power, HouseholdGoods, Health, Transport, Communication, Recreation&Culture, Education, Restaurants&Hotels, Goods&Services, AllExpenditure, OtherExpenditure, Total Exp, Income, Rating]
# Index: []

# %%
#Generating 1 values
for i in range(585):

    per=rnd.randint(40,81)
    pl_mi=rnd.randint(1,3)
    
    if pl_mi==1:
        per_val=df1.iloc[893,:]+df1.iloc[893,:]*(per/100)
    else:
        per_val=df1.iloc[893,:]-df1.iloc[893,:]*(per/100)
    
    df3=df3.append(per_val)
df3
# Out:
#      Food&Drinks  AlcoholicItems  Cloothing&Footwear  Fuel&Power  \
# 893       535.14            97.2               194.4      535.14
# 893      1724.34           313.2               626.4     1724.34
# 893      1773.89           322.2               644.4     1773.89
# 893       317.12            57.6               115.2      317.12
# 893       218.02            39.6                79.2      218.02
# ..           ...             ...                 ...         ...
# 893       465.77            84.6               169.2      465.77
# 893      1516.23           275.4               550.8     1516.23
# 893       445.95            81.0               162.0      445.95
# 893      1446.86           262.8               525.6     1446.86
# 893      1615.33           293.4               586.8     1615.33
#
#      HouseholdGoods  Health  Transport  Communication  Recreation&Culture  \
# 893           291.6    48.6     632.34          145.8              632.34
# ...

# %%
# df3.reset_index(inplace=True)
# df3.drop("index",axis=1,inplace=True)

# %%
df1["Rating"].value_counts()
# Out:
# 5.0    996
# 4.0    855
# 2.0    532
# 3.0    416
# 6.0    149
# 1.0     65
# Name: Rating, dtype: int64

# %%
df1.to_csv("S:\datacommit.csv")

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)

for train_index, test_index in split.split(df1,df1["Rating"]):
    
    train_set=df1.loc[train_index]
    test_set=df1.loc[test_index]

# %%
X_train=train_set.drop("Rating",axis=1)
y_train=train_set["Rating"]
X_test=test_set.drop("Rating",axis=1)
y_test=test_set["Rating"]

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2410, 16)
# (603, 16)
# (2410,)
# (603,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.linear_model import SGDClassifier
l=KNeighborsClassifier(n_neighbors=2,weights="distance")

# %%
l.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                      weights='distance')

# %%
y_pred=l.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7213930348258707
